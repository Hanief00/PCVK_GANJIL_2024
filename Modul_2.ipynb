# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanief00/PCVK_GANJIL_2024/blob/main/Modul_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/kenjaku.webp')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/kenjaku.webp', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray) #(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/kenjaku.webp', img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize = (10,10)) #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax =  fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100, 100), radius=50, color=(255, 0, 0), thickness=8)
plt.imshow(black_img)

# %% [markdown]
# # Bagian Baru

# %%
cv.line(black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255, 255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10, 500), fontFace=font, fontScale=4, color=(255, 255, 0), thickness=2, lineType = cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1, 1, 2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **PERTANYAAN**
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antar tipe data int16 dan int32?
# 3. Apakah kegunaan "google.colab.patches import cv2_imshow" pada potongan kode berikut :
# * from google.colab.patches import cv2_imshow
# * skimage import io
# 4. Apakah kegunaan "Skimage import io" pada potongan kode soal nomor 3
#
# **JAWABAN**
# 1. perbedaannya terletak pada penampilan gambar, apabila tanpa matplotlib maka penampilan ngambar secara langsung serta format gambar, ukuran, pengubahan warna sangat terbatas. sedangkan dengan menggunakan matplotlib kontrol terhadap ukuran, warna, skala gambar dapat terpenuhi. serta penambahan garis, lingkaran, dan lain lain juga bisa dilakukan, dan juga matplotlib menyediakan format gambar yang beragam.
#
# 2. perbedaannya terdapat pada ukuran memori yang lebih besar pada int32 dari pada int16, sedangkan secara visual tidak ada perbedaan karena menggunakan np.zeros maka setiap pixel gambar akan bernilai 0 saat ditampilkan dengan plt.imshow.
#
# 3. =4
# 4. dari google.colab.patches mengimport library cv2_imshow untuk menampilkan gambar. Sedangkan dari library skimage mengimport fungsi modul io untuk membaca gambar dari drive tadi menjadi array numpy dengan nilai float = [0,1].

# %% [markdown]
# **TUGAS**
#
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
# 3. Tampilkan image baris ke 20-115, kolom 25-120!
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!
# 6. Tampilkan image dengan posisi terbalik!
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran
# font, dan warna font yang sesuai keinginan anda.
# 10. Tunjukkan code program anda pada bapak/ibu dosen

# %% [markdown]
# 1.  ukuran pixelnya tidak berubah, akan tetapi area tampilan gambarnya saja yang diperbesar tidak seperti cv.resize yang dapat mengubah ukuran dan resolusi gambarnya. seperti pada praktikum diatas area gambar dengan figsize(10,10) maka area gambar yang ditampilkan sesuai figsize tersebut sedangkan ukuran pixel, resolusinya tidak berubah.

# %%
# Tugas 2

img_rb = img.copy()
img_rb[:, :, 1] = 0  # Channel 1
plt.imshow(img_rb)

# %%
img_gb = img.copy()
img_gb[:, :, 2] = 0  # Channel 2
plt.imshow(img_gb)

# %%
# TUGAS 3
img_baris = img[20:115, 25:120]
plt.imshow(img_baris)

# %%
# TUGAS 4
red_channel = img[5:30, :, 2]
plt.imshow(red_channel, cmap='Reds')
plt.title("Red Channel")
plt.show()

# %%
# TUGAS 5
# Create image
img_ayaka = cv.imread('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/ayaka.webp')

# Create 5 random boxes
cv.rectangle(img_ayaka, pt1=(200, 200), pt2=(300, 300), color=(0,0,255), thickness=7)
cv.rectangle(img_ayaka, pt1=(100, 150), pt2=(500, 300), color=(0,0,120), thickness=7)
cv.rectangle(img_ayaka, pt1=(90, 180), pt2=(330, 450), color=(0,220,105), thickness=7)
cv.rectangle(img_ayaka, pt1=(50, 20), pt2=(230, 360), color=(108,0,255), thickness=7)
cv.rectangle(img_ayaka, pt1=(250, 300), pt2=(100, 440), color=(0,200,0), thickness=7)

plt.imshow(cv.cvtColor(img_ayaka, cv.COLOR_BGR2RGB))
plt.title("Random Boxes")
plt.show()

# %%
# TUGAS 6

img_terbalik = cv.flip(cv.cvtColor(img_ayaka, cv.COLOR_BGR2RGB), 0)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize = (6,6)) #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax =  fig.add_subplot(111)
ax.imshow(img_terbalik)

# %%
# TUGAS 7
img_kegiatan = cv.imread('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/Kegiatan.jpg')
cv.rectangle(img_kegiatan, pt1=(4500, 2000), pt2=(3450, 3450), color=(0,0,255), thickness=10)
cv.circle(img_kegiatan, center=(3950, 2700), radius=500, color=(255, 0, 0), thickness=10)
plt.imshow(cv.cvtColor(img_kegiatan, cv.COLOR_BGR2RGB))
plt.show()

# %%
# TUGAS 8
img_kitten = cv.imread('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/kitten.jpg')
cv.rectangle(img_kitten, pt1=(60, 220), pt2=(5, 150), color=(255,100,255), thickness=2)
plt.imshow(cv.cvtColor(img_kitten, cv.COLOR_BGR2RGB))
plt.show()

# %%
# TUGAS 9
img_kitten2 = cv.imread('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/kitten.jpg')
cv.rectangle(img_kitten2, pt1=(60, 220), pt2=(5, 150), color=(255,100,255), thickness=2)
plt.imshow(cv.cvtColor(img_kitten2, cv.COLOR_BGR2RGB))
cv.putText(img_kitten2, text='MyKitten', org=(50, 80), fontFace=font, fontScale=2, color=(255, 255, 0), thickness=2, lineType = cv.LINE_AA)
plt.imshow(img_kitten2)
plt.show()

# %% [markdown]
# **TUGAS KELOMPOK**
#
# Kelompok 5 tutup bagian Foto dan Qr Code

# %%
img_ktm = cv.imread('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/KTM_Hanief Mochsin.jpg')
cv.rectangle(img_ktm, pt1=(300, 346), pt2=(150, 160), color=(0,255,0), thickness=10)
cv.rectangle(img_ktm, pt1=(180, 445), pt2=(265, 525), color=(0,80,255), thickness=7)
cv.circle(img_ktm, center=(220, 215), radius=44, color=(255, 0, 0), thickness=6)
plt.imshow(cv.cvtColor(img_ktm, cv.COLOR_BGR2RGB))
plt.show()

# %%
img_ktm1 = cv.imread('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/Ravi.jpeg')
cv.rectangle(img_ktm1, pt1=(320, 560), pt2=(40, 950), color=(0,255,0), thickness=10)
cv.rectangle(img_ktm1, pt1=(1254, 740), pt2=(1530, 470), color=(0,80,255), thickness=7)
cv.circle(img_ktm1, center=(180, 700), radius=85, color=(255, 0, 0), thickness=6)
plt.imshow(cv.cvtColor(img_ktm1, cv.COLOR_BGR2RGB))
plt.show()

# %%
img_ktm2 = cv.imread('/content/drive/MyDrive/Semester 5/Pengolahan Citra dan Visi Komputer/Fiqlal.jpeg')
cv.rectangle(img_ktm2, pt1=(320, 560), pt2=(20, 970), color=(0,255,0), thickness=10)
cv.rectangle(img_ktm2, pt1=(1280, 740), pt2=(1560, 470), color=(0,80,255), thickness=7)
cv.circle(img_ktm2, center=(170, 700), radius=100, color=(255, 0, 0), thickness=6)
plt.imshow(cv.cvtColor(img_ktm2, cv.COLOR_BGR2RGB))
plt.show()
